# %% [markdown]
# ## Estimate WM fractions (0-1) in the top 1000m of the Arctic Ocean using T, S, DO observations

# %%
# Load Arctic T, S, DO data

import pandas as pd
import numpy as np
import xarray as xr

data_path = '/Users/ko389/Documents/GitHub/Arctic_water_masses/Data/Arctic_T_S_DO_data.nc'
arctic = xr.open_dataset(data_path).to_dataframe()
# Out:
# /Users/ko389/miniconda3/envs/hydro_env_local/lib/python3.12/site-packages/xarray/coding/times.py:254: RuntimeWarning: invalid value encountered in cast
#   flat_num_dates_ns_int = (flat_num_dates * _NS_PER_TIME_DELTA[delta]).astype(

# %%
# Data preparation

def set_up_arctic_data(df):

    # rename & reorder columns
    df=df.rename(columns={'dissolved_oxygen':'oxygen','conservative_temperature':'conservative_temp'})
    column_order = ['conservative_temp', 'absolute_salinity', 'oxygen','latitude', 'longitude', 'depth', 'source','nprof', 'datetime']
    df = df [column_order]

    # remove labrador sea
    labrador_Sea = df[(df['latitude']<80)&(df['longitude']<-40)&(df['longitude']>-120)].index
    df = df.drop(labrador_Sea)

    # remove data with depth > 1000m
    df = df[df['depth']<1000]
    df = df.dropna(subset=['conservative_temp','absolute_salinity','oxygen'])
    
    return df

arctic = set_up_arctic_data(arctic)

# %%
# Make a copy of data and add mass column
df = arctic.copy()  
df["mass"] = 1.0

# Convert datetime column to string

# %%
# End members for source water types

# ASW: Arctic Surface Water
# sPW: Alaskan Coastal Current Water
# MMsPW: Modified summer Pacific Water
# wPW: winter Pacific Water
# NCW: Norwegian Current Water
# Modified NCW: Modified Atlantic Water
# BW: Brine-enriched Water

#Seasonal modification of end members:
#ASW in summer is T=-1.35, S=25.5, DO=367.25
#NCW in summer is T=12, S=35.3, DO=275.56
#MsPW is removed in winter

values = {
    'ASW_T': -1.45, 
    'ASW_S': 27,
    'ASW_O': 390.53,
    #'MsPW_T': 0.5, #Remove to test
    #'MsPW_S': 31,
    #'MsPW_O': 354.21,
    'sPW_T': 6,
    'sPW_S': 31.2,
    'sPW_O': 314,
    'wPW_T': -1.5,
    'wPW_S': 33.2,
    'wPW_O': 280.84,
    'NCW_T': 8, 
    'NCW_S': 35.4,
    'NCW_O': 287.82,
    'AW_T': 0.0, #####0.3 using post-2010 data######
    'AW_S': 35.05,
    'AW_O': 298,
    'BW_T': -1.8, #####-1.75 using post-2010 data######
    'BW_S': 34.45,
    'BW_O': 370
}

# %%
ASW = ["ASW", values['ASW_T'], values['ASW_S'], values['ASW_O']]    
#MsPW = ["MsPW", values['MsPW_T'], values['MsPW_S'], values['MsPW_O']]
sPW = ["sPW", values['sPW_T'], values['sPW_S'], values['sPW_O']]
wPW = ["wPW", values['wPW_T'], values['wPW_S'], values['wPW_O']] 
NCW = ["NCW ", values['NCW_T'], values['NCW_S'], values['NCW_O']] 
AW = ["AW", values['AW_T'], values['AW_S'], values['AW_O']] 
BW = ["BW", values['BW_T'], values['BW_S'], values['BW_O']] 

def prepare_endmember_df(endmembers_arr):
    df = pd.DataFrame(data=endmembers_arr,
                      columns=["endmember_name", "conservative_temp", "absolute_salinity","oxygen"
                               ])
    df["mass"] = 1
    return df

endmemberdf = prepare_endmember_df(
    [ASW,sPW,wPW,NCW,AW,BW]) #Add back MsPW if needed

endmemberdf 

#####REMOVE - no oxygen end members dataframe######
#endmemberdf_no_oxygen = endmemberdf.drop(columns=['oxygen'])
#endmemberdf_no_oxygen
# Out:
#   endmember_name  conservative_temp  absolute_salinity  oxygen  mass
# 0            ASW              -1.45              27.00  390.53     1
# 1           ACCW               6.00              31.20  314.00     1
# 2            wPW              -1.50              33.20  280.84     1
# 3           NCW                8.00              35.40  287.82     1
# 4            MAW               0.00              35.05  298.00     1
# 5             BW              -1.80              34.45  370.00     1

# %%
# Run code in chunks

import pyompa
from pyompa import (
    plot_ompasoln_endmember_fractions,
    plot_ompasoln_residuals,
    plot_ompasoln_endmember_usagepenalties
)

# Assuming 'df' is your DataFrame with 1522168 rows

chunk_size = 10000
num_chunks = len(df) // chunk_size + 1

# Define column titles
column_titles = ["ASW", "sPW","wPW","NCW","AW","BW"] # Add back in "MsPW" if needed

# Initialize empty DataFrames to store results
all_wm_fractions = pd.DataFrame(columns=column_titles)
all_residuals = pd.DataFrame(columns=['conservative_temp', 'absolute_salinity', 'oxygen']) 

convertedparamgroups = [
    pyompa.ConvertedParamGroup(
        groupname="phosphate_remin",
        conversion_ratios=[{"oxygen": -170, "phosphate": 1.0}],
        always_positive=False
    )
]

paramweightings = {
    "conservative_temp": 24,
    "absolute_salinity": 24,
    "oxygen": 7, 
    "mass": 24
}

hardmasscons_settings = {
    "param_names": ["conservative_temp", "absolute_salinity","oxygen","mass"], 
    "param_weightings": paramweightings,
    "convertedparam_groups": convertedparamgroups,
    "sumtooneconstraint": True,
    "standardize_by_watertypes": True
}

# Loop over chunks
for i in range(num_chunks):
    start_idx = i * chunk_size
    end_idx = min((i + 1) * chunk_size, len(df))
    
    # Extract chunk of data
    chunk_df = df.iloc[start_idx:end_idx]
    
     # Run the analysis with the hard mass conservation constraint for the current chunk
    ompasol = pyompa.OMPAProblem(
        obs_df=chunk_df.dropna(),
        **hardmasscons_settings
    ).solve(
        endmemberdf,
        endmember_name_column="endmember_name"
    )
    
    # Concatenate results to the overall DataFrames
    all_wm_fractions = pd.concat([all_wm_fractions, pd.DataFrame(ompasol.endmember_fractions, columns=column_titles)])
    all_residuals = pd.concat([all_residuals, pd.DataFrame(ompasol.param_residuals, columns=ompasol.param_names)])

# Reset index for the final DataFrame
all_wm_fractions.reset_index(drop=True, inplace=True)
all_residuals.reset_index(drop=True, inplace=True)

# Display the final DataFrames
print("All WM Fractions:")
print(all_wm_fractions)

print("\nAll Residuals:")
print(all_residuals)
# Out:
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 189157.41209492637
# Original weighted sum squares: 189157.41209492637
# Post fix weighted sum squared: 189161.5728192014
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 469742.5046718186
# Original weighted sum squares: 469742.5046718186
# Post fix weighted sum squared: 469746.2265845589
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 177948.9236988112
# Original weighted sum squares: 177948.9236988112
# Post fix weighted sum squared: 177950.6980125183
# objective: 177950.6980125183
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# /var/folders/zn/185xql1x357249zc9q1yjqvm0000gq/T/ipykernel_5575/1703813259.py:63: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_wm_fractions = pd.concat([all_wm_fractions, pd.DataFrame(ompasol.endmember_fractions, columns=column_titles)])
# /var/folders/zn/185xql1x357249zc9q1yjqvm0000gq/T/ipykernel_5575/1703813259.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_residuals = pd.concat([all_residuals, pd.DataFrame(ompasol.param_residuals, columns=ompasol.param_names)])
# status: optimal
# optimal value 270697.9893819674
# Original weighted sum squares: 270697.9893819674
# Post fix weighted sum squared: 270697.99582271586
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 246259.2020505166
# Original weighted sum squares: 246259.2020505166
# Post fix weighted sum squared: 246264.41356938402
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 225832.33187869954
# Original weighted sum squares: 225832.33187869954
# Post fix weighted sum squared: 225881.9406337508
# objective: 225881.9406337508
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 130030.66917500517
# Original weighted sum squares: 130030.66917500517
# Post fix weighted sum squared: 130030.6797675832
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 137365.99471542024
# Original weighted sum squares: 137365.99471542024
# Post fix weighted sum squared: 137367.6544502784
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 101685.60888824522
# Original weighted sum squares: 101685.60888824522
# Post fix weighted sum squared: 101687.42675416853
# objective: 101687.42675416851
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 369856.5947538478
# Original weighted sum squares: 369856.5947538478
# Post fix weighted sum squared: 369856.6643333838
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 392808.9346711795
# Original weighted sum squares: 392808.9346711795
# Post fix weighted sum squared: 392984.3725409508
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 355903.39240639185
# Original weighted sum squares: 355903.39240639185
# Post fix weighted sum squared: 355911.5194613217
# objective: 355911.51946132176
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 75710.03575358042
# Original weighted sum squares: 75710.03575358042
# Post fix weighted sum squared: 75710.88231181553
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 89329.57313188392
# Original weighted sum squares: 89329.57313188392
# Post fix weighted sum squared: 89330.17941788744
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 59658.698070103695
# Original weighted sum squares: 59658.698070103695
# Post fix weighted sum squared: 59659.936152420254
# objective: 59659.936152420254
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 86323.50995963525
# Original weighted sum squares: 86323.50995963525
# Post fix weighted sum squared: 86323.51093881151
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 95270.7114063782
# Original weighted sum squares: 95270.7114063782
# Post fix weighted sum squared: 95273.69985890905
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 74166.52179467084
# Original weighted sum squares: 74166.52179467084
# Post fix weighted sum squared: 74166.97105989575
# objective: 74166.97105989573
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 10462.744154040536
# Original weighted sum squares: 10462.744154040536
# Post fix weighted sum squared: 10463.44134709239
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 13405.058208568138
# Original weighted sum squares: 13405.058208568138
# Post fix weighted sum squared: 13405.76330572901
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 6363.13259026098
# Original weighted sum squares: 6363.13259026098
# Post fix weighted sum squared: 6364.089967869891
# objective: 6364.089967869891
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 9538.8857662969
# Original weighted sum squares: 9538.8857662969
# Post fix weighted sum squared: 9539.198990156203
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 13048.753583232425
# Original weighted sum squares: 13048.753583232425
# Post fix weighted sum squared: 13049.527606868696
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 5733.085159620074
# Original weighted sum squares: 5733.085159620074
# Post fix weighted sum squared: 5733.674786140962
# objective: 5733.674786140964
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 13138.985120793353
# Original weighted sum squares: 13138.985120793353
# Post fix weighted sum squared: 13140.41952545167
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 16066.481983044105
# Original weighted sum squares: 16066.481983044105
# Post fix weighted sum squared: 16067.724468016015
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 8897.486958729789
# Original weighted sum squares: 8897.486958729789
# Post fix weighted sum squared: 8898.593614898888
# objective: 8898.593614898888
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 5151.52994914758
# Original weighted sum squares: 5151.52994914758
# Post fix weighted sum squared: 5151.591939996448
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 8794.944781321887
# Original weighted sum squares: 8794.944781321887
# Post fix weighted sum squared: 8795.017558717162
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 1695.5688841706872
# Original weighted sum squares: 1695.5688841706872
# Post fix weighted sum squared: 1695.6803050412882
# objective: 1695.680305041288
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 9019.657018529317
# Original weighted sum squares: 9019.657018529317
# Post fix weighted sum squared: 9020.240266775123
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 12530.668673838725
# Original weighted sum squares: 12530.668673838725
# Post fix weighted sum squared: 12531.073099324884
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 4907.903066072452
# Original weighted sum squares: 4907.903066072452
# Post fix weighted sum squared: 4908.228548488838
# objective: 4908.228548488838
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 7981.058448893676
# Original weighted sum squares: 7981.058448893676
# Post fix weighted sum squared: 7981.392954719453
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 10818.488578589591
# Original weighted sum squares: 10818.488578589591
# Post fix weighted sum squared: 10819.04256054374
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 3693.296701960791
# Original weighted sum squares: 3693.296701960791
# Post fix weighted sum squared: 3693.432316888109
# objective: 3693.432316888109
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 12666.683779543291
# Original weighted sum squares: 12666.683779543291
# Post fix weighted sum squared: 12667.941910708698
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 19329.086528869077
# Original weighted sum squares: 19329.086528869077
# Post fix weighted sum squared: 19329.829474786267
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 9477.122300015923
# Original weighted sum squares: 9477.122300015923
# Post fix weighted sum squared: 9478.271560749965
# objective: 9478.271560749965
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 15107.322773493102
# Original weighted sum squares: 15107.322773493102
# Post fix weighted sum squared: 15109.138419932684
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 24307.260201132936
# Original weighted sum squares: 24307.260201132936
# Post fix weighted sum squared: 24308.265238264925
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 12084.15991253957
# Original weighted sum squares: 12084.15991253957
# Post fix weighted sum squared: 12085.2820936872
# objective: 12085.2820936872
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 16388.86913810073
# Original weighted sum squares: 16388.86913810073
# Post fix weighted sum squared: 16392.041834371445
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 24185.787872224137
# Original weighted sum squares: 24185.787872224137
# Post fix weighted sum squared: 24188.129891005854
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 13387.456707323818
# Original weighted sum squares: 13387.456707323818
# Post fix weighted sum squared: 13388.195099552366
# objective: 13388.195099552366
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 16349.814054097316
# Original weighted sum squares: 16349.814054097316
# Post fix weighted sum squared: 16352.079629178736
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 24326.585378922195
# Original weighted sum squares: 24326.585378922195
# Post fix weighted sum squared: 24327.56140458114
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 13416.637782471189
# Original weighted sum squares: 13416.637782471189
# Post fix weighted sum squared: 13417.400845616345
# objective: 13417.400845616345
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 14937.674422532085
# Original weighted sum squares: 14937.674422532085
# Post fix weighted sum squared: 14939.403780357738
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 22314.8027473102
# Original weighted sum squares: 22314.8027473102
# Post fix weighted sum squared: 22315.81766564861
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 11956.753364014265
# Original weighted sum squares: 11956.753364014265
# Post fix weighted sum squared: 11957.920201956129
# objective: 11957.92020195613
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 17119.055222300976
# Original weighted sum squares: 17119.055222300976
# Post fix weighted sum squared: 17123.184424301755
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 33900.10721151199
# Original weighted sum squares: 33900.10721151199
# Post fix weighted sum squared: 33901.18844435566
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 14473.501541987278
# Original weighted sum squares: 14473.501541987278
# Post fix weighted sum squared: 14476.062950151965
# objective: 14476.062950151965
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 2405.6507727207095
# Original weighted sum squares: 2405.6507727207095
# Post fix weighted sum squared: 2407.2044649800246
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 52797.250952926
# Original weighted sum squares: 52797.250952926
# Post fix weighted sum squared: 52800.481079485035
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 7.763059064123856
# Original weighted sum squares: 7.763059064123856
# Post fix weighted sum squared: 7.842380716354783
# objective: 7.842380716354783
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 1952.0140036502535
# Original weighted sum squares: 1952.0140036502535
# Post fix weighted sum squared: 1952.0309120725924
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 62317.87280817505
# Original weighted sum squares: 62317.87280817505
# Post fix weighted sum squared: 62317.87331989626
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 10.0901337695325
# Original weighted sum squares: 10.0901337695325
# Post fix weighted sum squared: 10.099521585907265
# objective: 10.099521585907265
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 2438.5120702567015
# Original weighted sum squares: 2438.5120702567015
# Post fix weighted sum squared: 2438.5381500084454
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 54228.886486090756
# Original weighted sum squares: 54228.886486090756
# Post fix weighted sum squared: 54228.88699918666
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 8.881741942703714
# Original weighted sum squares: 8.881741942703714
# Post fix weighted sum squared: 8.903118282435194
# objective: 8.903118282435194
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 2361.9093833159113
# Original weighted sum squares: 2361.9093833159113
# Post fix weighted sum squared: 2361.927124201843
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 51634.302486088985
# Original weighted sum squares: 51634.302486088985
# Post fix weighted sum squared: 51634.30291513418
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 8.106332028041567
# Original weighted sum squares: 8.106332028041567
# Post fix weighted sum squared: 8.114452414320871
# objective: 8.114452414320871
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 2094.577080034852
# Original weighted sum squares: 2094.577080034852
# Post fix weighted sum squared: 2095.6998247174074
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 56888.29906769619
# Original weighted sum squares: 56888.29906769619
# Post fix weighted sum squared: 56892.871716201735
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 8.64059022945708
# Original weighted sum squares: 8.64059022945708
# Post fix weighted sum squared: 8.786470660516688
# objective: 8.786470660516688
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 2426.6513468566745
# Original weighted sum squares: 2426.6513468566745
# Post fix weighted sum squared: 2426.6807605978656
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 58293.346579448014
# Original weighted sum squares: 58293.346579448014
# Post fix weighted sum squared: 58293.347163837156
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 9.045477179417407
# Original weighted sum squares: 9.045477179417407
# Post fix weighted sum squared: 9.057630370031525
# objective: 9.057630370031525
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 2214.7156564059414
# Original weighted sum squares: 2214.7156564059414
# Post fix weighted sum squared: 2214.7403298578893
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 54947.69622333818
# Original weighted sum squares: 54947.69622333818
# Post fix weighted sum squared: 54947.697854065984
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 8.815914051678215
# Original weighted sum squares: 8.815914051678215
# Post fix weighted sum squared: 8.854587328140287
# objective: 8.854587328140287
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 2468.784022091084
# Original weighted sum squares: 2468.784022091084
# Post fix weighted sum squared: 2470.7330472071826
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 53095.00074106177
# Original weighted sum squares: 53095.00074106177
# Post fix weighted sum squared: 53100.48577265562
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 8.286227530189985
# Original weighted sum squares: 8.286227530189985
# Post fix weighted sum squared: 8.42607981351234
# objective: 8.42607981351234
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 2571.178175730297
# Original weighted sum squares: 2571.178175730297
# Post fix weighted sum squared: 2573.2273567799048
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 53594.63965479741
# Original weighted sum squares: 53594.63965479741
# Post fix weighted sum squared: 53602.63792469706
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 8.74647939116444
# Original weighted sum squares: 8.74647939116444
# Post fix weighted sum squared: 8.916827575436526
# objective: 8.916827575436526
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 2907.0034957744238
# Original weighted sum squares: 2907.0034957744238
# Post fix weighted sum squared: 2909.040193231196
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 51749.52880146097
# Original weighted sum squares: 51749.52880146097
# Post fix weighted sum squared: 51754.407620469494
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 8.256180349244065
# Original weighted sum squares: 8.256180349244065
# Post fix weighted sum squared: 8.580242539332897
# objective: 8.580242539332897
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 1614.6756923421447
# Original weighted sum squares: 1614.6756923421447
# Post fix weighted sum squared: 1616.6667523359395
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 18424.032704355894
# Original weighted sum squares: 18424.032704355894
# Post fix weighted sum squared: 18429.065900243724
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 9.980120199592111
# Original weighted sum squares: 9.980120199592111
# Post fix weighted sum squared: 10.095220682877626
# objective: 10.095220682877626
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 1865.9066939911045
# Original weighted sum squares: 1865.9066939911045
# Post fix weighted sum squared: 1867.5876156247991
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 16329.560148414994
# Original weighted sum squares: 16329.560148414994
# Post fix weighted sum squared: 16329.709904018999
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 8.70781817847012
# Original weighted sum squares: 8.70781817847012
# Post fix weighted sum squared: 9.567686419659827
# objective: 9.567686419659829
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 1750.4543755612265
# Original weighted sum squares: 1750.4543755612265
# Post fix weighted sum squared: 1750.4804187756638
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 15704.600941772444
# Original weighted sum squares: 15704.600941772444
# Post fix weighted sum squared: 15708.29899078879
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 10.18863966231546
# Original weighted sum squares: 10.18863966231546
# Post fix weighted sum squared: 10.594935903589121
# objective: 10.594935903589121
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 1956.2080648475658
# Original weighted sum squares: 1956.2080648475658
# Post fix weighted sum squared: 1956.2578640951342
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 16776.948977268537
# Original weighted sum squares: 16776.948977268537
# Post fix weighted sum squared: 16779.05619422159
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 8.38953643880815
# Original weighted sum squares: 8.38953643880815
# Post fix weighted sum squared: 9.540968882089572
# objective: 9.540968882089572
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 2081.086096007503
# Original weighted sum squares: 2081.086096007503
# Post fix weighted sum squared: 2082.3316374969004
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 15141.337158427898
# Original weighted sum squares: 15141.337158427898
# Post fix weighted sum squared: 15142.63826111844
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 8.267178253276846
# Original weighted sum squares: 8.267178253276846
# Post fix weighted sum squared: 8.807118197600555
# objective: 8.807118197600555
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 1997.5756912794304
# Original weighted sum squares: 1997.5756912794304
# Post fix weighted sum squared: 1998.2950789813285
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 15799.568673171556
# Original weighted sum squares: 15799.568673171556
# Post fix weighted sum squared: 15799.88669139406
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 8.722144473911628
# Original weighted sum squares: 8.722144473911628
# Post fix weighted sum squared: 9.21518295367036
# objective: 9.21518295367036
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 1756.5384809039945
# Original weighted sum squares: 1756.5384809039945
# Post fix weighted sum squared: 1757.868135121201
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 17024.635468560147
# Original weighted sum squares: 17024.635468560147
# Post fix weighted sum squared: 17030.592520301732
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 9.742458572634941
# Original weighted sum squares: 9.742458572634941
# Post fix weighted sum squared: 9.925661744363515
# objective: 9.925661744363513
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 2012.484014062175
# Original weighted sum squares: 2012.484014062175
# Post fix weighted sum squared: 2014.2726972310925
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 14627.674972218963
# Original weighted sum squares: 14627.674972218963
# Post fix weighted sum squared: 14627.932280794623
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 9.674950251194167
# Original weighted sum squares: 9.674950251194167
# Post fix weighted sum squared: 9.730472696158994
# objective: 9.730472696158992
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 1978.1586296439446
# Original weighted sum squares: 1978.1586296439446
# Post fix weighted sum squared: 1979.5605591172289
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 15309.346944197725
# Original weighted sum squares: 15309.346944197725
# Post fix weighted sum squared: 15312.654564698267
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 9.523233138006383
# Original weighted sum squares: 9.523233138006383
# Post fix weighted sum squared: 9.643543447624285
# objective: 9.643543447624287
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 1826.5108309459386
# Original weighted sum squares: 1826.5108309459386
# Post fix weighted sum squared: 1827.9767551971267
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 15550.025787893861
# Original weighted sum squares: 15550.025787893861
# Post fix weighted sum squared: 15550.169315859233
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 8.832275779699419
# Original weighted sum squares: 8.832275779699419
# Post fix weighted sum squared: 8.896597200656547
# objective: 8.896597200656547
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 355164497.69600475
# Original weighted sum squares: 355164497.69600475
# Post fix weighted sum squared: 355258120.3947546
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 356492922.6445425
# Original weighted sum squares: 356492922.6445425
# Post fix weighted sum squared: 356518627.01849306
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 355116300.32499576
# Original weighted sum squares: 355116300.32499576
# Post fix weighted sum squared: 355257839.22458994
# objective: 355257839.2245898
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 20297035.972239926
# Original weighted sum squares: 20297035.972239926
# Post fix weighted sum squared: 20305143.532197762
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 20383810.16271482
# Original weighted sum squares: 20383810.16271482
# ...
# objective: 2.8904822970543522
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 748.184773107967
# Original weighted sum squares: 748.184773107967
# Post fix weighted sum squared: 748.24304088909
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 19905.738504186964
# Original weighted sum squares: 19905.738504186964
# Post fix weighted sum squared: 19905.79354958515
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 1.9856560338514109
# Original weighted sum squares: 1.9856560338514109
# Post fix weighted sum squared: 2.9273163948732477
# objective: 2.9273163948732477
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 600.0400002191749
# Original weighted sum squares: 600.0400002191749
# Post fix weighted sum squared: 600.1548117865262
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 19151.5851246894
# Original weighted sum squares: 19151.5851246894
# Post fix weighted sum squared: 19153.106958532797
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 2.983669750880867
# Original weighted sum squares: 2.983669750880867
# Post fix weighted sum squared: 3.0995322348094145
# objective: 3.099532234809414
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 666.1931727422829
# Original weighted sum squares: 666.1931727422829
# Post fix weighted sum squared: 666.2674048957616
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 18216.147738484888
# Original weighted sum squares: 18216.147738484888
# Post fix weighted sum squared: 18218.719737444684
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 2.6680488614178817
# Original weighted sum squares: 2.6680488614178817
# Post fix weighted sum squared: 2.7049251387045183
# objective: 2.7049251387045183
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 752.4548349578016
# Original weighted sum squares: 752.4548349578016
# Post fix weighted sum squared: 752.5023470682462
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 21304.55679630855
# Original weighted sum squares: 21304.55679630855
# Post fix weighted sum squared: 21304.61858683785
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 2.290158959221038
# Original weighted sum squares: 2.290158959221038
# Post fix weighted sum squared: 2.712850226108946
# objective: 2.712850226108946
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 733.4873670705688
# Original weighted sum squares: 733.4873670705688
# Post fix weighted sum squared: 733.6149600076909
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 20268.367974754492
# Original weighted sum squares: 20268.367974754492
# Post fix weighted sum squared: 20268.402081664193
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 2.6689720075350634
# Original weighted sum squares: 2.6689720075350634
# Post fix weighted sum squared: 2.941769889790845
# objective: 2.9417698897908444
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 616.7806167151896
# Original weighted sum squares: 616.7806167151896
# Post fix weighted sum squared: 616.9148806656609
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 16829.143465183817
# Original weighted sum squares: 16829.143465183817
# Post fix weighted sum squared: 16829.97433100763
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 2.8118202566892894
# Original weighted sum squares: 2.8118202566892894
# Post fix weighted sum squared: 2.961771344954939
# objective: 2.961771344954939
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 653.9695614759785
# Original weighted sum squares: 653.9695614759785
# Post fix weighted sum squared: 654.1932351724757
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 12206.681081614839
# Original weighted sum squares: 12206.681081614839
# Post fix weighted sum squared: 12209.470072517572
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 4.3740852574414575
# Original weighted sum squares: 4.3740852574414575
# Post fix weighted sum squared: 4.525824698440436
# objective: 4.525824698440436
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 594.2993224877578
# Original weighted sum squares: 594.2993224877578
# Post fix weighted sum squared: 594.7397174794385
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 12716.685263548496
# Original weighted sum squares: 12716.685263548496
# Post fix weighted sum squared: 12721.366214549387
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 4.19269023059177
# Original weighted sum squares: 4.19269023059177
# Post fix weighted sum squared: 4.303162885903206
# objective: 4.303162885903206
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 671.6749004409937
# Original weighted sum squares: 671.6749004409937
# Post fix weighted sum squared: 671.8200498471138
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 12259.322018363255
# Original weighted sum squares: 12259.322018363255
# Post fix weighted sum squared: 12261.564568244881
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 4.250727799078346
# Original weighted sum squares: 4.250727799078346
# Post fix weighted sum squared: 4.4041390771039195
# objective: 4.40413907710392
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 674.3796226498489
# Original weighted sum squares: 674.3796226498489
# Post fix weighted sum squared: 674.5736842113897
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 12845.329646310105
# Original weighted sum squares: 12845.329646310105
# Post fix weighted sum squared: 12847.450403160456
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 3.9451701279420752
# Original weighted sum squares: 3.9451701279420752
# Post fix weighted sum squared: 4.4201338794036555
# objective: 4.4201338794036555
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 606.6373692129135
# Original weighted sum squares: 606.6373692129135
# Post fix weighted sum squared: 606.9605950965697
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 12224.079218581066
# Original weighted sum squares: 12224.079218581066
# Post fix weighted sum squared: 12228.766204560592
# On example 0 to 10000 out of 10000
# status: optimal
# optimal value 4.770222637854265
# Original weighted sum squares: 4.770222637854265
# Post fix weighted sum squared: 5.091277870112723
# objective: 5.091277870112722
# Endmember-idx mapping is
#  OrderedDict({'ASW': [0], 'ACCW': [1], 'wPW': [2], 'NCW ': [3], 'MAW': [4], 'BW': [5]})
# I'm assuming that the index encoding mass is: [3]
# Std used for normalization: [ 4.32046487  3.18946181 45.80109799  1.        ]
# Mean used for normalization: [  1.54166667  32.71666667 323.53166667   0.        ]
# params to use: ['conservative_temp', 'absolute_salinity', 'oxygen', 'mass']
# param weighting: [24 24  7 24]
# effective weighting: [ 5.5549578   7.52478048  0.15283476 24.        ]
# Matrix A:
# Trying convertedvariable sign constraint: [1]
# On example 0 to 9492 out of 9492
# status: optimal
# optimal value 1220.482778560745
# Original weighted sum squares: 1220.482778560745
# Post fix weighted sum squared: 1221.053691175765
# Trying convertedvariable sign constraint: [-1]
# On example 0 to 9492 out of 9492
# status: optimal
# optimal value 11245.453844167032
# Original weighted sum squares: 11245.453844167032
# Post fix weighted sum squared: 11247.911008659754
# On example 0 to 9492 out of 9492
# status: optimal
# optimal value 38.93390015518473
# Original weighted sum squares: 38.93390015518473
# Post fix weighted sum squared: 39.09297385423045
# objective: 39.09297385423045
# All WM Fractions:
#               ASW      ACCW       wPW       NCW       MAW        BW
# 0        0.014000  0.013913  0.005994  0.939820  0.023635  0.002638
# 1        0.014436  0.012651  0.006532  0.936089  0.027575  0.002716
# 2        0.002031  0.001647  0.000350  0.790444  0.116658  0.088871
# 3        0.005167  0.005183  0.002005  0.764840  0.222074  0.000732
# 4        0.001792  0.001451  0.000743  0.779260  0.134490  0.082264
# ...           ...       ...       ...       ...       ...       ...
# 1179487  0.006817  0.006664  0.002164  0.169572  0.813435  0.001347
# 1179488  0.006790  0.006608  0.002229  0.171058  0.812244  0.001071
# 1179489  0.000000  0.000000  0.000000  0.000000  0.000000  1.000000
# 1179490  0.000000  0.000000  0.000000  0.000000  0.000000  1.000000
# 1179491  0.000000  0.000000  0.000000  0.000000  0.000000  1.000000
#
# [1179492 rows x 6 columns]
#
# All Residuals:
#          conservative_temp  absolute_salinity        oxygen          mass
# 0            -8.881784e-16       0.000000e+00  0.000000e+00  0.000000e+00
# 1            -2.664535e-15       7.105427e-15  5.684342e-14  0.000000e+00
# 2            -8.881784e-16       0.000000e+00  0.000000e+00 -1.110223e-16
# 3            -1.776357e-15       0.000000e+00  5.684342e-14  0.000000e+00
# 4            -8.881784e-16       0.000000e+00  0.000000e+00  0.000000e+00
# ...                    ...                ...           ...           ...
# 1179487       1.110223e-15       0.000000e+00  0.000000e+00  0.000000e+00
# 1179488       1.110223e-15       7.105427e-15 -5.684342e-14  0.000000e+00
# 1179489       6.000000e-02      -3.000000e-02 -1.854082e-03  0.000000e+00
# 1179490       5.900000e-02      -3.000000e-02 -1.829452e-03  0.000000e+00
# 1179491       3.400000e-02      -3.800000e-02 -1.307046e-03  0.000000e+00
#
# [1179492 rows x 4 columns]

# %%
all_residuals
# Out:
#          conservative_temp  absolute_salinity        oxygen          mass
# 0            -3.552714e-15      -7.105427e-15  0.000000e+00 -1.110223e-16
# 1            -2.664535e-15      -7.105427e-15  5.684342e-14 -1.110223e-16
# 2            -3.552714e-15       0.000000e+00  5.684342e-14  0.000000e+00
# 3            -2.664535e-15       0.000000e+00  0.000000e+00  0.000000e+00
# 4            -3.552714e-15       7.105427e-15  5.684342e-14  2.220446e-16
# ...                    ...                ...           ...           ...
# 1179487       0.000000e+00       0.000000e+00  0.000000e+00  0.000000e+00
# 1179488       0.000000e+00      -7.105427e-15 -5.684342e-14 -1.110223e-16
# 1179489       6.000000e-02      -3.000000e-02 -1.358259e-03  0.000000e+00
# 1179490       5.900000e-02      -3.000000e-02 -1.342130e-03  0.000000e+00
# 1179491       3.400000e-02      -3.800000e-02 -1.053423e-03  0.000000e+00
#
# [1179492 rows x 4 columns]

# %%
# Combine the results with the original data

arctic.reset_index(drop=True, inplace=True)
all_wm_fractions = pd.concat([arctic, all_wm_fractions[['ASW', 'NCW', 'AW', 'sPW','wPW', 'BW']]],axis=1) #Add back 'MsPW' if needed

#rename residuals columns
#all_residuals.columns = ['conservative_temp_residuals', 'absolute_salinity_residuals', 'oxygen_residuals', 'mass_residuals']
#arctic.reset_index(drop=True, inplace=True)
#all_residuals= pd.concat([arctic, all_residuals],axis=1)

# %%
# Ensure 'datetime' is properly formatted as a coordinate
df = all_wm_fractions.copy()
df['datetime'] = pd.to_datetime(df['datetime'])

# Convert to xarray Dataset (without setting too many indices)
ds = xr.Dataset.from_dataframe(df)

# Save to NetCDF
output_path = "/Users/ko389/Documents/GitHub/Arctic_water_masses/Data/OMP_output_no_MsPW.nc"#_without_DO.nc"
ds.to_netcdf(output_path, engine="netcdf4")
